# %%
from dotenv import load_dotenv

# %%
load_dotenv(override=True)
# Out:
# True

# %%
import os
openai_api_key=os.getenv("OPENAI_API_KEY")
if openai_api_key:
    print(f"OpenAI API Key exists and begins {openai_api_key[:8]}")
else:
    print("OPENAI_API_KEY is not set")
# Out:
# OpenAI API Key exists and begins sk-proj-

# %%
from openai import OpenAI

# %%
openai = OpenAI()

# %%
messages = [{"role": "user", "content": "what is 2+2?"} ]

# %%
response = openai.chat.completions.create(
    model="gpt-4o-mini",
    messages=messages
)
print(response.choices[0].message.content)
#print(response)
# Out:
# 2 + 2 equals 4.

# %%
questions = ["Please propose a hard, challenging question to assess someone's IQ. Respond only with the question."]
messages = [{"role": "user", "content": questions[0]}]
response = openai.chat.completions.create(
    model="gpt-4o-mini",
    messages=messages
)
question=response.choices[0].message.content 
print(question)
# Out:
# If a train leaves a station traveling at 60 miles per hour and another train leaves the same station two hours later traveling at 90 miles per hour, how far from the station will the two trains meet?

# %%
messages = [{"role": "user", "content": question}]
response = openai.chat.completions.create(
    model="gpt-4o-mini",
    messages=messages
)

answer=response.choices[0].message.content
print(answer)
# Out:
# Let's denote the time in hours that the first train travels as \( t \). Given that the first train departs two hours earlier than the second train, the second train will travel for \( t - 2 \) hours when they meet.
#
# The distance traveled by the first train can be calculated using the formula:
#
# \[
# \text{Distance} = \text{Speed} \times \text{Time}
# \]
#
# For the first train:
#
# \[
# \text{Distance}_{\text{first}} = 60t
# \]
#
# For the second train:
#
# \[
# \text{Distance}_{\text{second}} = 90(t - 2)
# \]
#
# At the point they meet, the distances traveled will be equal:
#
# \[
# 60t = 90(t - 2)
# \]
#
# Now, we'll solve for \( t \):
#
# 1. Expand the right side:
#
# \[
# 60t = 90t - 180
# \]
#
# 2. Move all terms involving \( t \) to one side:
#
# \[
# 60t - 90t = -180
# \]
#
# 3. Combine like terms:
#
# \[
# -30t = -180
# \]
#
# 4. Solve for \( t \):
#
# \[
# t = \frac{-180}{-30} = 6
# \]
#
# Now, we know that the first train travels for 6 hours. To find the distance from the station where they meet:
#
# \[
# \text{Distance} = 60t = 60 \times 6 = 360 \text{ miles}
# \]
#
# Thus, the two trains will meet **360 miles from the station**.

# %%
from IPython.display import Markdown, display
display(Markdown(answer))
# Out:
# Let's denote the time in hours that the first train travels as \( t \). Given that the first train departs two hours earlier than the second train, the second train will travel for \( t - 2 \) hours when they meet.
#
# The distance traveled by the first train can be calculated using the formula:
#
# \[
# \text{Distance} = \text{Speed} \times \text{Time}
# \]
#
# For the first train:
#
# \[
# \text{Distance}_{\text{first}} = 60t
# \]
#
# For the second train:
#
# \[
# \text{Distance}_{\text{second}} = 90(t - 2)
# \]
#
# At the point they meet, the distances traveled will be equal:
#
# \[
# 60t = 90(t - 2)
# \]
#
# Now, we'll solve for \( t \):
#
# 1. Expand the right side:
#
# \[
# 60t = 90t - 180
# \]
#
# 2. Move all terms involving \( t \) to one side:
#
# \[
# 60t - 90t = -180
# \]
#
# 3. Combine like terms:
#
# \[
# -30t = -180
# \]
#
# 4. Solve for \( t \):
#
# \[
# t = \frac{-180}{-30} = 6
# \]
#
# Now, we know that the first train travels for 6 hours. To find the distance from the station where they meet:
#
# \[
# \text{Distance} = 60t = 60 \times 6 = 360 \text{ miles}
# \]
#
# Thus, the two trains will meet **360 miles from the station**.
